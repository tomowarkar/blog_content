# %%
from scipy import signal
import matplotlib.pyplot as plt
# %matplotlib inline

P = 2
K = 7 
T = 0.1

# 伝達関数の定義
num = [P*K] # 分子の係数
den = [T,1, 0] # 分母の係数
G = signal.lti(num, den)

# ボード線図の計算
w, mag, phase = signal.bode(G)

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.semilogx(w, mag, label="Gain[dB]")
ax2.semilogx(w, phase, color="r", label="Phase[deg]")

ax1.set_ylim([-40, 0])
ax2.set_ylim([-180, -90])

handler1, label1 = ax1.get_legend_handles_labels()
handler2, label2 = ax2.get_legend_handles_labels()

ax1.legend(handler1 + handler2, label1 + label2, loc=2)

plt.grid()
plt.show()

# %%
print([i for i, n in enumerate(mag) if abs(n)<1])
(w[74]+w[75])/2, (mag[74]+mag[75])/2, (phase[74]+phase[75])/2,
# Out:
# [74]
# (10.24638589654775, -0.396638551725832, -135.66552511615305)

# %%
from scipy import signal
import matplotlib.pyplot as plt
# %matplotlib inline

P = 10
K = 7 
T = 0.1
D = 0.32

# 伝達関数の定義
num = [P*K] # 分子の係数
den = [T, (1+D*K), 0] # 分母の係数
G = signal.lti(num, den)

# ボード線図の計算
w, mag, phase = signal.bode(G)

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.semilogx(w, mag, label="Gain[dB]")
ax2.semilogx(w, phase, color="r", label="Phase[deg]")

ax1.set_ylim([-40, 0])
ax2.set_ylim([-180, -90])

handler1, label1 = ax1.get_legend_handles_labels()
handler2, label2 = ax2.get_legend_handles_labels()

ax1.legend(handler1 + handler2, label1 + label2, loc=2)

plt.grid()
plt.show()

# %%
w[81], mag[81], phase[81]
# Out:
# (18.73817422860385, -0.016591441955984203, -120.04245696799563)
